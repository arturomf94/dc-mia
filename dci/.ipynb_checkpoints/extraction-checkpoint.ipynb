# %%
# En esta notebook de jupyter se trabaja la extracción de los datos conforme a lo que 
# requieren las instrucciones. 

# Avances:

# Se leyeron todos los archivos para convertirlos en dataframes en pandas.
# Se procesaron los dataframes para extraer una versión sintetizada de los datos de
# productos. Por ahora, se omite la ruta de quesos por ser diferente a las otras rutas.

# %%
import pandas as pd
import sys
import glob
import os.path

# %%
folder_name = "./data/"

data_path = os.path.join(folder_name,'*xlsx')

files = glob.glob(data_path)

# %%
files
# Out:
# ['./data/v2017.xlsx',
#  './data/v2012.xlsx',
#  './data/v2013.xlsx',
#  './data/v2015.xlsx',
#  './data/v2018.xlsx',
#  './data/v2014.xlsx',
#  './data/v2016.xlsx']

# %%
data_frames = []
for file in files:
    df = pd.read_excel(file, sheet_name = None)
    data_frames.append(df)

# %%
test = data_frames[0]['Hoja1']
test
# Out:
#                Unnamed: 0                                   Unnamed: 1  \
# 0                     NaN                                          NaN
# 1                     NaN  SEMANA DEL   31       AL 5      ENERO  2017
# 2                     NaN                                          NaN
# 3                     NaN                                 RUTA: FERMIN
# 4                     NaN                                          NaN
# 5                PRODUCTO                                    PRODUCTO8
# 6                   CARGA                                           90
# 7              EXISTENCIA                                            0
# 8              DEVOLUCION                                            2
# 9             VENTA TOTAL                                           88
# 10        PRECIO * PRODUC                                          5.5
# 11                      $                                          484
# ...

# %%
test.shape[1]
# Out:
# 130

# %%
# new_test = test.iloc[5:13,0:8].T
# new_test['meta'] = 'TEST'
# new_test

# %%
cols = ['PRODUCTO', 'CARGA', 'EXISTENCIA', 'DEVOLUCION', 'VENTA TOTAL', 'PRECIO * PRODUC', '$', 'VENTA EN LT', 'RUTA', 'DIA', 'SEMANA']
productos = pd.DataFrame(columns= cols)

# %%
rutas = []
semanas = []
dias = []
test_copy = test
for i in range(int(test.shape[0])):
    for j in range(int(test.shape[1])):
        if type(test.iloc[i, j]) == unicode and 'RUTA:' in test.iloc[i, j]:
            ruta = ''
            dia = ''
            semana = ''
            ruta = test.iloc[i, j]
            if not(test.iloc[i, j] in rutas):
                rutas.append(ruta)
            if type(test.iloc[i - 1,j]) == unicode:
                dia = test.iloc[i - 1, j]
                if not(test.iloc[i - 1, j] in dias):
                    dias.append(dia)
            if type(test.iloc[i - 2,j]) == unicode and 'SEMANA' in test.iloc[i - 2,j]:
                semana = test.iloc[i - 2, j]
                if not(test.iloc[i - 2, j] in semanas):
                    semanas.append(semana)
            new_entry = test_copy.iloc[i + 2:i + 10, j:j + 12].T
            new_entry['RUTA'] = ruta
            new_entry['DIA'] = dia
            new_entry['SEMANA'] = semana
            new_entry.columns = cols
            print(new_entry.head())            
            # print(list(new_entry.columns.values))
            if ruta != '' and not 'QUESO' in ruta:
                productos = productos.append(new_entry, ignore_index=True)
# Out:
#                     PRODUCTO CARGA EXISTENCIA DEVOLUCION VENTA TOTAL  \
# Unnamed: 1         PRODUCTO8    90          0          2          88
# CONTROL DE VENTAS  PRODUCTO3    70          5          0          65
# Unnamed: 3         PRODUCTO7    60          0          3          57
# Unnamed: 4         PRODUCTO2    50          0          2          48
# Unnamed: 5         PRODUCTO1    60          4          3          53
#
#                   PRECIO * PRODUC      $ VENTA EN LT          RUTA DIA  \
# Unnamed: 1                    5.5    484          18  RUTA: FERMIN
# CONTROL DE VENTAS               8    520         6.5  RUTA: FERMIN
# Unnamed: 3                    5.5  313.5           6  RUTA: FERMIN
# Unnamed: 4                      5    240     9.25926  RUTA: FERMIN
# Unnamed: 5                    9.5  503.5          28  RUTA: FERMIN
#
#                                                         SEMANA
# Unnamed: 1         SEMANA DEL   31       AL 5      ENERO  2017
# ...

# %%
productos
# Out:
#            PRODUCTO CARGA EXISTENCIA DEVOLUCION VENTA TOTAL PRECIO * PRODUC  \
# 1         PRODUCTO8    90          0          2          88             5.5
# 3        PRODUCTO10   NaN        NaN        NaN         NaN              13
# 5        PRODUCTO10   NaN        NaN        NaN           0               8
# 7         PRODUCTO8   NaN        NaN        NaN           0             5.5
# 9        PRODUCTO10   NaN        NaN          0           0              14
# 11       PRODUCTO10   NaN        NaN          0           0             7.5
# 13       PRODUCTO10   NaN          0          0           0               8
# 15        PRODUCTO8    50         14          2          34               6
# 17       PRODUCTO10   NaN        NaN        NaN         NaN            11.5
# 19       PRODUCTO10   NaN        NaN          0           0             7.5
# 21        PRODUCTO8    80          0         10          70               6
# ...

# %%
productos = productos.loc[productos['CARGA'] != 'CARGA']

# %%
productos.loc[productos['SEMANA'] == 'SEMANA DEL   31       AL 5      ENERO  2017']
# Out:
#         PRODUCTO CARGA EXISTENCIA DEVOLUCION VENTA TOTAL PRECIO * PRODUC  \
# 1      PRODUCTO8    90          0          2          88             5.5
# 1384   PRODUCTO8    90          0          2          88             5.5
# 1485   PRODUCTO8    90          0          2          88             5.5
# 2676   PRODUCTO8    90          0          2          88             5.5
# 2677   PRODUCTO3    70          5          0          65               8
# 2678   PRODUCTO7    60          0          3          57             5.5
# 2679   PRODUCTO2    50          0          2          48               5
# 2680   PRODUCTO1    60          4          3          53             9.5
# 2681   PRODUCTO5   100         37          1          62              14
# 2682   PRODUCTO9   NaN        NaN        NaN           0              16
# 2683         NaN   NaN        NaN        NaN         NaN             NaN
# 2684         NaN   NaN        NaN        NaN         NaN             NaN
# ...

# %%
rutas
# Out:
# [u'RUTA: FERMIN',
#  u'RUTA: JUGUERAS',
#  u'RUTA: SAN MARCOS',
#  u'RUTA: QUESOS',
#  u'RUTA:MARTIN',
#  u'RUTA: MARTIN',
#  u'RUTA: ERICK']

# %%
dias
# Out:
# [u'SABADO',
#  u'DIA:LUNES ',
#  u'DIA LUNES ',
#  u'DIA DOMIN',
#  u'DIA MARTES ',
#  u'DIA MERTES ',
#  u'MIERCOLES',
#  u'DIA MIERCOLES ',
#  u'DIA MIERCO',
#  u'jueves',
#  u'DIA JUEVES  ',
#  u'DIA JUEVES ',
#  u'JUEVE4S',
#  u' DIA VIERNES ',
#  u'DIA VIERNES ',
#  u'VIERNES',
#  u'miercoles',
#  u'martes',
#  u'DIA: SABADO',
#  u'DIA: LUNES',
#  u'DIA: MARTES',
#  u'DIA: MIERCOLES',
#  u'DIA: JUEVES',
#  u'DIA: VIERNES']

# %%
semanas
# Out:
# [u'SEMANA DEL   31       AL 5      ENERO  2017',
#  u'SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013 ',
#  u'SEMANA DEL   7        AL    13    ENERO  2017',
#  u'SEMANA DEL      21    AL     27   ENERO  2017',
#  u'SEMANA DEL      4    AL     10   FEBRERO    2017',
#  u'SEMANA DEL      11     AL     17    FEBRERO    2017',
#  u'SEMANA DEL      18     AL     24      FEBRERO    2017',
#  u'SEMANA DEL     25        FEBRERO  al  3 febrero 2017',
#  u'SEMANA DEL     4   al          10  marzo   2017',
#  u'SEMANA DEL     11  al        17   marzo   2017',
#  u'SEMANA DEL     18   al      24   marzo   2017',
#  u'SEMANA DEL     25   al     31   marzo   2017',
#  u'SEMANA DEL     1   al     7   ABRIL   2017',
#  u'SEMANA DEL     8    al    14   ABRIL   2017',
#  u'SEMANA DEL     15     al    21     ABRIL   2017',
#  u'SEMANA DEL     22     al    28      ABRIL   2017',
#  u'SEMANA DEL     29    al        5 mayo     2017']

# %%
def extract_product_tables(df): 
    cols = ['PRODUCTO', 'CARGA', 'EXISTENCIA', 'DEVOLUCION', 'VENTA TOTAL', 'PRECIO * PRODUC', '$', 'VENTA EN LT', 'RUTA', 'DIA', 'SEMANA']
    productos = pd.DataFrame(columns= cols)
    test_copy = df
    for i in range(int(df.shape[0])):
        for j in range(int(df.shape[1])):
            if type(df.iloc[i, j]) == unicode and 'RUTA:' in df.iloc[i, j]:
                ruta = ''
                dia = ''
                semana = ''
                ruta = df.iloc[i, j]
                if type(df.iloc[i - 1,j]) == unicode:
                    dia = df.iloc[i - 1, j]
                if type(df.iloc[i - 2,j]) == unicode and 'SEMANA' in df.iloc[i - 2,j]:
                    semana = df.iloc[i - 2, j]
                new_entry = test_copy.iloc[i + 2:i + 10, j:j + 12].T
                new_entry['RUTA'] = ruta
                new_entry['DIA'] = dia
                new_entry['SEMANA'] = semana
                new_entry.columns = cols
                if ruta != '' and not 'QUESO' in ruta:
                    productos = productos.append(new_entry, ignore_index=True)
    return productos

# %%
productos = extract_product_tables(data_frames[0]['Hoja1'])

# %%
productos
# Out:
#            PRODUCTO  CARGA  EXISTENCIA  DEVOLUCION  VENTA TOTAL  \
# 0         PRODUCTO8     90           0           2           88
# 1         PRODUCTO3     70           5           0           65
# 2         PRODUCTO7     60           0           3           57
# 3         PRODUCTO2     50           0           2           48
# 4         PRODUCTO1     60           4           3           53
# 5         PRODUCTO5    100          37           1           62
# 6         PRODUCTO9    NaN         NaN         NaN            0
# 7               NaN    NaN         NaN         NaN          NaN
# 8               NaN    NaN         NaN         NaN          NaN
# 9               NaN    NaN         NaN         NaN          NaN
# 10              NaN    NaN         NaN         NaN          NaN
# 11         PRODUCTO  CARGA  EXISTENCIA  DEVOLUCION  VENTA TOTAL
# 12       PRODUCTO10    NaN         NaN         NaN          NaN
# 13      Queso Hebra    NaN         NaN         NaN            0
# ...
