# %%
# En este notebook se hizo una restructuración de la entrega previa. 
# Se procedió a hacer una limpia de las variables relevantes para las preguntas. 
# Sin embargo, todavía no se construyen las consultas que responden las preguntas. 
# Esperamos que mañana tengamos la respuesta a todas las preguntas de la etapa 1-3
# Podemos observar que algunas preguntas más generales se pueden responder, como: 
# ¿Cuáles son las distintas rutas en todos los años?
# ¿Cuáles son los productos de todos los años?

# %%
import pandas as pd
import numpy as np
import sys
import glob
import os.path
import re

# %%
folder_name = "./data/"

data_path = os.path.join(folder_name,'*xlsx')

files = glob.glob(data_path)

# %%
files
# Out:
# ['./data/v2017.xlsx',
#  './data/v2012.xlsx',
#  './data/v2013.xlsx',
#  './data/v2015.xlsx',
#  './data/v2018.xlsx',
#  './data/v2014.xlsx',
#  './data/v2016.xlsx']

# %%
years = []
for file in files:
    df = pd.read_excel(file, sheet_name = None)
    year = file.replace('./data/v', '')
    year = year.replace('.xlsx', '')
    years.append([df, year])
    df['Hoja1'].to_pickle(year)

# %%
def extract_product_tables(df): 
    cols = ['PRODUCTO', 'CARGA', 'EXISTENCIA', 'DEVOLUCION', 'VENTA TOTAL', 'PRECIO * PRODUC', '$', 'VENTA EN LT', 'RUTA', 'DIA', 'SEMANA']
    productos = pd.DataFrame(columns= cols)
    test_copy = df
    for i in range(int(df.shape[0])):
        for j in range(int(df.shape[1])):
            if type(df.iloc[i, j]) == unicode and ('RUTA:' in df.iloc[i, j] or 'IVAN' in df.iloc[i, j]):
                ruta = ''
                dia = ''
                semana = ''
                ruta = df.iloc[i, j]
                dia = df.iloc[i - 1, j]
                semana = df.iloc[i - 2, j]
                new_entry = test_copy.iloc[i + 2:i + 10, j:j + 12].T
                new_entry['RUTA'] = ruta
                new_entry['DIA'] = dia
                new_entry['SEMANA'] = semana
                new_entry.columns = cols
                if ruta != '' and not 'QUESO' in ruta:
                    productos = productos.append(new_entry, ignore_index=True)
    return productos

# %%
cols = ['PRODUCTO', 'CARGA', 'EXISTENCIA', 'DEVOLUCION', 'VENTA TOTAL', 'PRECIO * PRODUC', '$', 'VENTA EN LT', 'RUTA', 'DIA', 'SEMANA', 'ANIO']
productos = pd.DataFrame(columns= cols)
for year in years:
    year_raw = year[0]['Hoja1']
    year_name = year[1]
    year_products = extract_product_tables(year_raw)
    year_products['ANIO'] = year_name
    productos = productos.append(year_products, ignore_index=True)

# %%
productos.shape
# Out:
# (90919, 12)

# %%
productos.to_pickle('productos')

# %%
productos = pd.read_pickle('productos')

# %%
# LIMPIAA!

# %%
# Queremos eliminar todas las observaciones que no son rutas
# Maldito Ivan.
rutas = []
for ruta in productos['RUTA']:
    if not ruta in rutas:
        rutas.append(ruta)
rutas
# Out:
# [u'RUTA: FERMIN',
#  u'RUTA: JUGUERAS',
#  u'RUTA: SAN MARCOS',
#  u'RUTA:MARTIN',
#  u'RUTA: MARTIN',
#  u'RUTA: ERICK',
#  u'RUTA: JESUS',
#  u'RUTA: TRADICION',
#  u'RUTA IVAN',
#  u'QHR IVAN',
#  u'QH IVAN',
#  u'RUTA IVAN ',
#  u'BALANCE SEMANAL IVAN ',
#  u'IVAN ']

# %%
productos = productos.loc[productos['RUTA'] != 'QHR IVAN']
productos = productos.loc[productos['RUTA'] != 'QH IVAN']
productos = productos.loc[productos['RUTA'] != 'BALANCE SEMANAL IVAN ']
productos = productos.loc[productos['RUTA'] != 'IVAN ']
rutas = []
for ruta in productos['RUTA']:
    if not ruta in rutas:
        rutas.append(ruta)
rutas
# Out:
# [u'RUTA: FERMIN',
#  u'RUTA: JUGUERAS',
#  u'RUTA: SAN MARCOS',
#  u'RUTA:MARTIN',
#  u'RUTA: MARTIN',
#  u'RUTA: ERICK',
#  u'RUTA: JESUS',
#  u'RUTA: TRADICION',
#  u'RUTA IVAN',
#  u'RUTA IVAN ']

# %%
# Ahora redefinimos repetidos: 
productos = productos.replace('RUTA:MARTIN', 'RUTA: MARTIN')
productos = productos.replace('RUTA IVAN ', 'RUTA: IVAN')
productos = productos.replace('RUTA IVAN', 'RUTA: IVAN')
rutas = []
for ruta in productos['RUTA']:
    if not ruta in rutas:
        rutas.append(ruta)
rutas
# Out:
# [u'RUTA: FERMIN',
#  u'RUTA: JUGUERAS',
#  u'RUTA: SAN MARCOS',
#  'RUTA: MARTIN',
#  u'RUTA: ERICK',
#  u'RUTA: JESUS',
#  u'RUTA: TRADICION',
#  'RUTA: IVAN']

# %%
productos_nombres = []
for producto in productos['PRODUCTO']:
    if not producto in productos_nombres:
        productos_nombres.append(producto)
productos_nombres
# Out:
# [u'PRODUCTO8',
#  u'PRODUCTO3',
#  u'PRODUCTO7',
#  u'PRODUCTO2',
#  u'PRODUCTO1',
#  u'PRODUCTO5',
#  u'PRODUCTO9',
#  nan,
#  nan,
#  nan,
#  nan,
#  u'PRODUCTO',
#  u'PRODUCTO10',
#  u'Queso Hebra',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  u'Queso fresco',
#  u'Queso a\xf1ejo',
#  u'Queso panela',
#  u'PRODUCTO4',
#  u'Requeson',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  u'PRODUCTO1 bolsa',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
# Elmininamos nan's en productos
productos = productos[productos['PRODUCTO'].isnull() == False]
productos_nombres = []
for producto in productos['PRODUCTO']:
    if not producto in productos_nombres:
        productos_nombres.append(producto)
productos_nombres
# Out:
# [u'PRODUCTO8',
#  u'PRODUCTO3',
#  u'PRODUCTO7',
#  u'PRODUCTO2',
#  u'PRODUCTO1',
#  u'PRODUCTO5',
#  u'PRODUCTO9',
#  u'PRODUCTO',
#  u'PRODUCTO10',
#  u'Queso Hebra',
#  u'Queso fresco',
#  u'Queso a\xf1ejo',
#  u'Queso panela',
#  u'PRODUCTO4',
#  u'Requeson',
#  u'PRODUCTO1 bolsa',
#  6,
#  8,
#  u'Queso hebra',
#  u'LTRS',
#  u'TOTAL QUESO',
#  50,
#  10.6,
#  55.3,
#  12.5,
#  41.629999999999995,
#  45.78,
#  44.25,
#  45.05,
#  0,
#  49.8,
#  57.6,
#  11.95,
#  40,
#  77.1,
#  21.6,
#  89.7,
#  15,
#  49.55,
#  49.08,
#  u'MS',
#  67.8,
#  52.8,
#  25,
#  74.5,
#  u'TOTAL QUES',
#  5.3,
#  58.5,
#  13.3,
#  7.5,
#  73.5,
#  10.8,
#  52.5,
#  8.5,
#  11.6,
#  42.7,
#  2.7,
#  14.9,
#  75,
#  4.4,
#  15.8,
#  44.9,
#  2.8,
#  59.5,
#  2.6,
#  5,
#  57.4,
#  41.5,
#  4.6,
#  42.3,
#  29.4,
#  16.6,
#  62.4,
#  2.5,
#  45,
#  8.7,
#  u'L-G-I',
#  0.3,
#  41.6,
#  37.5,
#  36,
#  39.5,
#  30,
#  43.7,
#  5.4,
#  50.1,
#  27.9,
#  43,
#  54.5,
#  21,
#  58.92,
#  22.5,
#  70.9,
#  34.8,
#  45.3,
#  54.9,
#  58.099999999999994,
#  4,
#  0.4,
#  49.6,
#  52,
#  3.5,
#  50.5,
#  2,
#  43.2,
#  56.8,
#  46.05,
#  89.2,
#  62.7,
#  61,
#  48.78,
#  26.400000000000002,
#  51.900000000000006,
#  1.96,
#  60,
#  25.1,
#  67,
#  54.3,
#  16.4,
#  74.4,
#  11,
#  45.6,
#  41.8,
#  40.1,
#  48,
#  32.3,
#  18.1,
#  64.4,
#  7.3,
#  6.9,
#  109.2,
#  31.700000000000003,
#  11.1,
#  99.2,
#  50.39,
#  9.6,
#  78,
#  19.9,
#  20.15,
#  40.6,
#  1.6,
#  9.25,
#  61.2,
#  56.400000000000006,
#  3.06,
#  8.2,
#  u'DEVOLUCION',
#  26.6,
#  52.800000000000004,
#  1.5,
#  1.66]

# %%
# Eliminamos productos invalidos
productos['PRODUCTO'] = productos['PRODUCTO'].apply(unicode)
productos = productos[productos['PRODUCTO'].str.contains("PRO") | productos['PRODUCTO'].str.contains("QUES") | productos['PRODUCTO'].str.contains("Ques")]
productos_nombres = []
for producto in productos['PRODUCTO']:
    if not producto in productos_nombres:
        productos_nombres.append(producto)
productos_nombres
# Out:
# [u'PRODUCTO8',
#  u'PRODUCTO3',
#  u'PRODUCTO7',
#  u'PRODUCTO2',
#  u'PRODUCTO1',
#  u'PRODUCTO5',
#  u'PRODUCTO9',
#  u'PRODUCTO',
#  u'PRODUCTO10',
#  u'Queso Hebra',
#  u'Queso fresco',
#  u'Queso a\xf1ejo',
#  u'Queso panela',
#  u'PRODUCTO4',
#  u'PRODUCTO1 bolsa',
#  u'Queso hebra',
#  u'TOTAL QUESO',
#  u'TOTAL QUES']

# %%
# Estandarizamos nombres
productos = productos.replace('PRODUCTO1 bolsa', 'PRODUCTO1')
productos = productos.replace('TOTAL QUES', 'TOTAL QUESO')
productos_nombres = []
for producto in productos['PRODUCTO']:
    if not producto in productos_nombres:
        productos_nombres.append(producto)
productos_nombres
# Out:
# [u'PRODUCTO8',
#  u'PRODUCTO3',
#  u'PRODUCTO7',
#  u'PRODUCTO2',
#  u'PRODUCTO1',
#  u'PRODUCTO5',
#  u'PRODUCTO9',
#  u'PRODUCTO',
#  u'PRODUCTO10',
#  u'Queso Hebra',
#  u'Queso fresco',
#  u'Queso a\xf1ejo',
#  u'Queso panela',
#  u'PRODUCTO4',
#  u'Queso hebra',
#  u'TOTAL QUESO']

# %%
# Eliminamos todas las observaciones que sean en realidad los nombres de las columnas
productos = productos.loc[productos['CARGA'] != 'CARGA']

# %%
dias = []
for dia in productos['DIA']:
    if not dia in dias:
        dias.append(dia)
dias
# Out:
# ['',
#  u'SABADO',
#  u'DIA:LUNES ',
#  u'DIA LUNES ',
#  u'DIA DOMIN',
#  u'DIA MARTES ',
#  u'DIA MERTES ',
#  u'MIERCOLES',
#  u'DIA MIERCOLES ',
#  u'DIA MIERCO',
#  u'jueves',
#  u'DIA JUEVES  ',
#  u'DIA JUEVES ',
#  u' DIA VIERNES ',
#  u'DIA VIERNES ',
#  u'miercoles',
#  u'martes',
#  u'DIA: SABADO',
#  u'DIA: LUNES',
#  u'DIA: MARTES',
#  u'DIA: MIERCOLES',
#  u'DIA: JUEVES',
#  u'DIA: VIERNES',
#  u'DIA: SABADO 07 07 2012',
#  u'DIA: SABADO 07-07-12',
#  u'DIA:LUNES  09-07-2012',
#  u'DIA: LUNES 9-07-12',
#  u'DIA:LUNES      09/07/12',
#  u'DIA: LUNES-DOMINGO 08 Y 09 /07/12',
#  u'DIA: DOMINGO 08-07-12',
#  u'DIA:MARTES 10-07-12',
#  u'DIA: MARTES 26-06-12',
#  u'DIA: MARTES 10-07-12',
#  u'DIA: MIERCOLES 11-07-12',
#  u'DIA:MIERCOLES 11/07/12',
#  u'DIA:JUEVES        12 /07/12',
#  u'DIA: JUEVES 12-07-12',
#  u'DIA:VIERNES      13/07/12',
#  u'DIA: VIERNES 13-07-12',
#  u'DIA: SABADO 14-07-12',
#  u'DIA:LUNES  16-07-2012',
#  u'DIA: LUNES 16-06-12',
#  u'DIA:LUNES  16-07-12',
#  u'DIA: LUNES 16-07-12',
#  u'DIA: DOMINGO 15-07-12',
#  u'DIA:MARTES 17-07-12',
#  u'DIA: MARTES 17-07-12',
#  u'DIA: MIERCOLES 18-07-12',
#  u'DIA:MIERCOLES 18/07/12',
#  u'DIA:JUEVES 19-07-12',
#  u'DIA: JUEVES 19-07-12',
#  u'DIA:VIERNES 20-07-12',
#  u'DIA: VIERNES 20-07-12',
#  u'SABADO 21 07 12',
#  u'sabado',
#  u'LUNES 23 07 12 ',
#  u'MARTES  24 07 12',
#  u'MRTES 24 07 12 ',
#  u'MIERCOLES 25 07 12',
#  u'MIERCOLES 25  07 12',
#  u'MIERCOL',
#  u'JUEVES 26 07 12',
#  u' VIERNES 27 07 12',
#  u'DIA SABADO',
#  u'DIA DOMINGO',
#  u'DIA:MARTES ',
#  u'DIA:VIERNES  03 DE AGOSTO DEL 2012',
#  u'DIA  SABADO  4 08 12',
#  u'SABADO 4 08 12',
#  u'DIA LUNES 6 08 12',
#  u'DIA MARTES  7  08  12 ',
#  u'DIA MARTES 7 08 12',
#  u'DIA MERTES 7 08 12',
#  u'MARTES  ',
#  u'DIA MIERCOLES 7 08 12 ',
#  u'DI MIERCOLES 8 08 12',
#  u'DIA MIERCOLES 80 08 12',
#  u'DIA JUEVES 9 08 12',
#  u'DIA JUEVES  9 08 12',
#  u'DIA VIERNES 10 AGOSTO 2012',
#  u'DIA VIERNES 10 08 12',
#  u'DIA SABADO 11 08 12',
#  u'DIA  LUNES  13  08  12',
#  u'DIA LUNES 13  08 12',
#  u'DIA LUNES 13 08 12 ',
#  u'DIA MARTES 14  08 12 ',
#  u'DIA MIERCOLES    14 08 12',
#  u'DIA MIERCOLES 15 08 12',
#  u'DIA JUEVES 16 08 12',
#  u'DIA VIERNES 17 08 12',
#  u'DIA SABADO   18  08  12',
#  u'DIA SABADO   18 08 12',
#  u'DIA SABADO    18 08 12',
#  u'DI LUNES ',
#  u'DIA LUNES  ',
#  u'MIERCOLES  ',
#  u'JUEVES ',
#  u'DIA VIERNES 24 08 12',
#  u'DIA VIERNES',
#  u'MIERCOLES ',
#  u'SABADO ',
#  u' DOMINGO',
#  u'MARTES',
#  u'MARTES ',
#  u'JUEVES',
#  u'VIERNES',
#  u'VIERNNES',
#  u'DIA:JUEVES      ',
#  u'DIA SABADO   ',
#  u'DIA SABADO  ',
#  u'DIA SABADO ',
#  u'VIERNES  ',
#  u'viernes',
#  u'SEMANA DEL8   AL 14   DE JUNIO 2013',
#  u'SEMANA DEL  22     AL 28       DE JUNIO 2013',
#  u'sabado ',
#  u'SEMANA DEL 7 AL 13 DE SEMTIEMBRE DEL 2013',
#  u'27     de  junio   al   2   de julio   2015',
#  u'4     de   al    10   de julio   2015',
#  u'11  de julio  al  17  de julio  2015  ',
#  u'18   de julio  al  24      de julio  2015  ',
#  u'2  de agosto    al  8      de agosto    2015  ',
#  u'miercos',
#  u'lunes']

# %%
# Filtramos aquellas observaciones que claramente no son dias
productos = productos[productos['DIA'].str.contains("SAB") | productos['DIA'].str.contains("DOM") | 
                         productos['DIA'].str.contains("LUN") | productos['DIA'].str.contains("MAR") | 
                         productos['DIA'].str.contains("MIER") | productos['DIA'].str.contains("JUE") | 
                         productos['DIA'].str.contains("VIE") | productos['DIA'].str.contains("sab") | 
                         productos['DIA'].str.contains("dom") | productos['DIA'].str.contains("lun") | 
                         productos['DIA'].str.contains("mar") | productos['DIA'].str.contains("mier") | 
                         productos['DIA'].str.contains("jue") | productos['DIA'].str.contains("vie")]
dias = []
for dia in productos['DIA']:
    if not dia in dias:
        dias.append(dia)
dias
# Out:
# [u'SABADO',
#  u'DIA:LUNES ',
#  u'DIA LUNES ',
#  u'DIA DOMIN',
#  u'DIA MARTES ',
#  u'MIERCOLES',
#  u'DIA MIERCOLES ',
#  u'DIA MIERCO',
#  u'jueves',
#  u'DIA JUEVES  ',
#  u'DIA JUEVES ',
#  u' DIA VIERNES ',
#  u'DIA VIERNES ',
#  u'miercoles',
#  u'martes',
#  u'DIA: SABADO',
#  u'DIA: LUNES',
#  u'DIA: MARTES',
#  u'DIA: MIERCOLES',
#  u'DIA: JUEVES',
#  u'DIA: VIERNES',
#  u'DIA: SABADO 07 07 2012',
#  u'DIA: SABADO 07-07-12',
#  u'DIA:LUNES  09-07-2012',
#  u'DIA: LUNES 9-07-12',
#  u'DIA:LUNES      09/07/12',
#  u'DIA: LUNES-DOMINGO 08 Y 09 /07/12',
#  u'DIA: DOMINGO 08-07-12',
#  u'DIA:MARTES 10-07-12',
#  u'DIA: MARTES 26-06-12',
#  u'DIA: MARTES 10-07-12',
#  u'DIA: MIERCOLES 11-07-12',
#  u'DIA:MIERCOLES 11/07/12',
#  u'DIA:JUEVES        12 /07/12',
#  u'DIA: JUEVES 12-07-12',
#  u'DIA:VIERNES      13/07/12',
#  u'DIA: VIERNES 13-07-12',
#  u'DIA: SABADO 14-07-12',
#  u'DIA:LUNES  16-07-2012',
#  u'DIA: LUNES 16-06-12',
#  u'DIA:LUNES  16-07-12',
#  u'DIA: LUNES 16-07-12',
#  u'DIA: DOMINGO 15-07-12',
#  u'DIA:MARTES 17-07-12',
#  u'DIA: MARTES 17-07-12',
#  u'DIA: MIERCOLES 18-07-12',
#  u'DIA:MIERCOLES 18/07/12',
#  u'DIA:JUEVES 19-07-12',
#  u'DIA: JUEVES 19-07-12',
#  u'DIA:VIERNES 20-07-12',
#  u'DIA: VIERNES 20-07-12',
#  u'SABADO 21 07 12',
#  u'sabado',
#  u'LUNES 23 07 12 ',
#  u'MARTES  24 07 12',
#  u'MIERCOLES 25 07 12',
#  u'MIERCOLES 25  07 12',
#  u'MIERCOL',
#  u'JUEVES 26 07 12',
#  u' VIERNES 27 07 12',
#  u'DIA SABADO',
#  u'DIA DOMINGO',
#  u'DIA:MARTES ',
#  u'DIA:VIERNES  03 DE AGOSTO DEL 2012',
#  u'DIA  SABADO  4 08 12',
#  u'SABADO 4 08 12',
#  u'DIA LUNES 6 08 12',
#  u'DIA MARTES  7  08  12 ',
#  u'DIA MARTES 7 08 12',
#  u'MARTES  ',
#  u'DIA MIERCOLES 7 08 12 ',
#  u'DI MIERCOLES 8 08 12',
#  u'DIA MIERCOLES 80 08 12',
#  u'DIA JUEVES 9 08 12',
#  u'DIA JUEVES  9 08 12',
#  u'DIA VIERNES 10 AGOSTO 2012',
#  u'DIA VIERNES 10 08 12',
#  u'DIA SABADO 11 08 12',
#  u'DIA  LUNES  13  08  12',
#  u'DIA LUNES 13  08 12',
#  u'DIA LUNES 13 08 12 ',
#  u'DIA MARTES 14  08 12 ',
#  u'DIA MIERCOLES    14 08 12',
#  u'DIA MIERCOLES 15 08 12',
#  u'DIA JUEVES 16 08 12',
#  u'DIA VIERNES 17 08 12',
#  u'DIA SABADO   18  08  12',
#  u'DIA SABADO   18 08 12',
#  u'DIA SABADO    18 08 12',
#  u'DI LUNES ',
#  u'DIA LUNES  ',
#  u'MIERCOLES  ',
#  u'JUEVES ',
#  u'DIA VIERNES 24 08 12',
#  u'DIA VIERNES',
#  u'MIERCOLES ',
#  u'SABADO ',
#  u' DOMINGO',
#  u'MARTES',
#  u'MARTES ',
#  u'JUEVES',
#  u'VIERNES',
#  u'VIERNNES',
#  u'DIA:JUEVES      ',
#  u'DIA SABADO   ',
#  u'DIA SABADO  ',
#  u'DIA SABADO ',
#  u'VIERNES  ',
#  u'viernes',
#  u'sabado ',
#  u'miercos',
#  u'lunes']

# %%
# Estandarizamos los dias:
dias_real = []
for dia in dias:
    if "SAB" in dia:
        dia = 'SABADO'
        dias_real.append(dia)
    if "DOM" in dia:
        dia = 'DOMINGO'
        dias_real.append(dia)
    if "LUN" in dia:
        dia = 'LUNES'
        dias_real.append(dia)
    if "MAR" in dia:
        dia = 'MARTES'
        dias_real.append(dia)
    if "MIE" in dia:
        dia = 'MIERCOLES'
        dias_real.append(dia)
    if "JUE" in dia:
        dia = 'JUEVES'
        dias_real.append(dia)
    if "VIE" in dia:
        dia = 'VIERNES'
        dias_real.append(dia)
    if "sab" in dia:
        dia = 'SABADO'
        dias_real.append(dia)
    if "dom" in dia:
        dia = 'DOMINGO'
        dias_real.append(dia)
    if "lun" in dia:
        dia = 'LUNES'
        dias_real.append(dia)
    if "mar" in dia:
        dia = 'MARTES'
        dias_real.append(dia)
    if "mie" in dia:
        dia = 'MIERCOLES'
        dias_real.append(dia)
    if "jue" in dia:
        dia = 'JUEVES'
        dias_real.append(dia)
    if "vie" in dia:
        dia = 'VIERNES'
        dias_real.append(dia)

for i in range(len(dias)):
    productos = productos.replace(dias[i], dias_real[i])

dias = []
for dia in productos['DIA']:
    if not dia in dias:
        dias.append(dia)
dias
# Out:
# ['SABADO', 'LUNES', 'DOMINGO', 'MARTES', 'MIERCOLES', 'JUEVES', 'VIERNES']

# %%
productos = productos.loc[productos['SEMANA'] != '']
semanas = []
for semana in productos['SEMANA']:
    if not semana in semanas:
        semanas.append(semana)
semanas
# Out:
# [u'SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013 ',
#  u'SEMANA DEL 07 AL 13 DE JULIO DEL 2012',
#  u'SEMANA DEL 14 AL 20 DE JULIO DEL 2012',
#  u'SEMANA DEL 21 AL 27 DE JULIO 2012',
#  u'SEMANA DE L21 AL 27 JULIO 2012',
#  u'SEMANA DEL  21 AL 27 DE JULIIO 2012',
#  u'SEMANA DEL 21 AL 237 DE JULIO 2012',
#  u'SEMANA DEL 21 AL 27  DE JULIO 2012',
#  u'SEMANA DEL 21 AL 27 2012',
#  u'SEMANA DEL 21 AL 27 DE JULIO DE 2102',
#  u'SEMANA DEL 28 DE JULIO AL 3 DE AGOSTO 2012',
#  u'SEMANA DE L 4 AGOTO AL 10  2012',
#  u'SEMANA DEL 4 AL 10 AGOSTO 2012',
#  u'SEMANA DEL 4 AL 10 AGOSTO 2012 ',
#  u'SEMANA  DEL 4  AL 10 AGOSTO 2012',
#  u'SEMANA DEL 4  AL 10 AGOSTO 2012',
#  u'SEMANA DEL 4 AL 10 DE AGOSTO 2012',
#  u'SEMANA  DE 4  AL 10 AGOSTO 2012',
#  u'SEMANA DEL 4 AL 10  AGOSTO 2012',
#  u'SEMANA DEL 4 AL 10 AGSTO  2012',
#  u'SEMANA DEL 4 A L 10 AGOSTO 2012',
#  u'SEMANA DEL 4 AL 10 DE AGOSTO 21402',
#  u'SEMANA DEL 40AL 10 AGOSTO 2012 ',
#  u'SEMANA DEL 4 AL 10 AGOSTO 2102 ',
#  u'SEMANA DEL 4 AL 10  AGOSTO 2012 ',
#  u'SEMANA DEL 4 0AL 10 AGOSTO 2012 ',
#  u'SEMANA DEL 11 AL 17 DE AGOSTO 2012 ',
#  u'SEMANA DE  11 AL 17 DE AGOSTO 2012',
#  u'SEMANA DEL 11 AL 17 DE  AGOSTO 2012',
#  u'SEMANADEL   11            AL          17     octubre  2014    ',
#  u'SEMANADEL   18             AL          24      octubre  2014    ',
#  u'SEMANADEL   25            AL          31     octubre  2014    ',
#  u'SEMANADEL   1          AL       7       NOVIEMBRE  2014    ',
#  u'SEMANADEL   8           AL         14       NOVIEMBRE  2014    ',
#  u'SEMANADEL   8          AL          15       NOVIEMBRE  2014    ',
#  u'SEMANADEL   15          AL         21         NOVIEMBRE  2014    ']

# %%
productos
# Out:
#            PRODUCTO CARGA EXISTENCIA DEVOLUCION  VENTA TOTAL PRECIO * PRODUC  \
# 60       PRODUCTO10   NaN        NaN          0          0.0             7.5
# 61      Queso Hebra   NaN        NaN          0          0.0              60
# 62     Queso fresco   NaN          0          0          0.0              12
# 63      Queso añejo   NaN          0          0          0.0              55
# 64     Queso panela   NaN          0          0          0.0              50
# 65        PRODUCTO4   NaN          0          0          0.0               6
# 67        PRODUCTO5   NaN          0          0          0.0              14
# 68        PRODUCTO1   NaN          0          0          0.0               9
# 69        PRODUCTO7   NaN          0          0          0.0               5
# 70        PRODUCTO3   NaN          0          0          0.0             7.5
# 71        PRODUCTO8   NaN          0          0          0.0               5
# 108      PRODUCTO10   NaN        NaN          0          0.0             7.5
# 109     Queso Hebra   NaN          0          0          0.0              60
# 110    Queso fresco   NaN          0          0          0.0              12
# 111     Queso añejo   NaN          0          0          0.0              55
# 112    Queso panela   NaN          0          0          0.0              50
# 113       PRODUCTO4   NaN          0          0          0.0               6
# 115       PRODUCTO5   NaN          0          0          0.0              14
# 116       PRODUCTO1   NaN          0          0          0.0               9
# 117       PRODUCTO7   NaN          0          0          0.0               5
# 118       PRODUCTO3   NaN          0          0          0.0             7.5
# 119       PRODUCTO8   NaN          0          0          0.0               5
# 216      PRODUCTO10   300        NaN        NaN        300.0            7.75
# 217     Queso Hebra   NaN        NaN        NaN          0.0              60
# 218    Queso fresco   NaN        NaN        NaN          0.0              12
# 219     Queso añejo   NaN        NaN        NaN          0.0              55
# 220    Queso panela   NaN        NaN        NaN          0.0              50
# 221       PRODUCTO4   NaN        NaN        NaN          0.0               6
# 223       PRODUCTO5   NaN        NaN        NaN          0.0              14
# 224       PRODUCTO1   NaN        NaN        NaN          0.0               7
# ...             ...   ...        ...        ...          ...             ...
# 90802   Queso añejo   NaN          0          0          0.0              55
# 90803  Queso panela   NaN          0          0          0.0              50
# 90804     PRODUCTO4   NaN          0          0          0.0               6
# 90806     PRODUCTO5   NaN          0          0          0.0              14
# 90807     PRODUCTO1   NaN          0          0          0.0               9
# 90808     PRODUCTO7   NaN          0          0          0.0               5
# 90809     PRODUCTO3   NaN          0          0          0.0             7.5
# 90810     PRODUCTO8   NaN          0          0          0.0               5
# 90835    PRODUCTO10   NaN        NaN          0          0.0             7.5
# 90836   Queso Hebra   NaN          0          0          0.0              60
# 90837  Queso fresco   NaN          0          0          0.0              12
# 90838   Queso añejo   NaN          0          0          0.0              55
# 90839  Queso panela   NaN          0          0          0.0              50
# 90840     PRODUCTO4   NaN          0          0          0.0               6
# 90842     PRODUCTO5   NaN          0          0          0.0              14
# 90843     PRODUCTO1   NaN          0          0          0.0               9
# 90844     PRODUCTO7   NaN          0          0          0.0               5
# 90845     PRODUCTO3   NaN          0          0          0.0             7.5
# 90846     PRODUCTO8   NaN          0          0          0.0               5
# 90907    PRODUCTO10   288        NaN        NaN        288.0             7.5
# 90908   Queso Hebra   NaN        NaN        NaN          0.0              60
# 90909  Queso fresco   NaN        NaN        NaN          0.0              12
# 90910   Queso añejo   NaN        NaN        NaN          0.0              55
# 90911  Queso panela   NaN        NaN        NaN          0.0              50
# 90912     PRODUCTO4   NaN        NaN        NaN          0.0               6
# 90914     PRODUCTO5   NaN        NaN        NaN          0.0              14
# 90915     PRODUCTO1   NaN        NaN        NaN          0.0               7
# 90916     PRODUCTO7   NaN        NaN        NaN          0.0               5
# 90917     PRODUCTO3   NaN        NaN        NaN          0.0             7.5
# 90918     PRODUCTO8   NaN        NaN        NaN          0.0               5
#
#             $  VENTA EN LT              RUTA      DIA  \
# 60        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 61        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 62        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 63        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 64        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 65        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 67        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 68        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 69        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 70        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 71        0.0          0.0  RUTA: SAN MARCOS    LUNES
# 108       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 109       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 110       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 111       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 112       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 113       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 115       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 116       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 117       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 118       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 119       0.0          0.0  RUTA: SAN MARCOS   MARTES
# 216    2325.0        300.0  RUTA: SAN MARCOS  VIERNES
# 217       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 218       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 219       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 220       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 221       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 223       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 224       0.0          0.0  RUTA: SAN MARCOS  VIERNES
# ...       ...          ...               ...      ...
# 90802     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90803     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90804     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90806     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90807     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90808     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90809     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90810     0.0          0.0  RUTA: SAN MARCOS    LUNES
# 90835     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90836     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90837     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90838     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90839     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90840     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90842     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90843     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90844     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90845     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90846     0.0          0.0  RUTA: SAN MARCOS   MARTES
# 90907  2160.0        288.0  RUTA: SAN MARCOS  VIERNES
# 90908     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90909     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90910     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90911     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90912     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90914     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90915     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90916     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90917     0.0          0.0  RUTA: SAN MARCOS  VIERNES
# 90918     0.0          0.0  RUTA: SAN MARCOS  VIERNES
#
#                                         SEMANA  ANIO
# 60     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 61     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 62     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 63     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 64     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 65     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 67     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 68     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 69     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 70     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 71     SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 108    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 109    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 110    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 111    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 112    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 113    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 115    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 116    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 117    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 118    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 119    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 216    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 217    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 218    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 219    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 220    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 221    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 223    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# 224    SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2017
# ...                                        ...   ...
# 90802  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90803  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90804  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90806  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90807  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90808  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90809  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90810  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90835  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90836  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90837  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90838  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90839  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90840  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90842  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90843  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90844  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90845  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90846  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90907  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90908  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90909  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90910  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90911  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90912  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90914  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90915  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90916  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90917  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
# 90918  SEMANA DEL 24 AL 30 DE AGOSTO DEL 2013   2016
#
# [18017 rows x 12 columns]

# %%
# Estandarizamos semanas

# Funcion auxiliar: 

def is_int(value):
  try:
    int(value)
    return True
  except ValueError:
    return False

semanas_real = []
error_indices = []
for semana in semanas:
    semana_copy = semana
    error_index = semanas.index(semana)
    if 'ene' in semana or 'ene'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' ENERO' 
        semanas_real.append(semana)
    if 'feb' in semana or 'feb'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' FEBRERO' 
        semanas_real.append(semana)
    if 'mar' in semana or 'mar'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' MARZO' 
        semanas_real.append(semana)
    if 'abr' in semana or 'abr'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' ABRIL' 
        semanas_real.append(semana)
    if 'may' in semana or 'may'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' MAYO' 
        semanas_real.append(semana)
    if 'jun' in semana or 'jun'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' JUNIO' 
        semanas_real.append(semana)
    if 'jul' in semana or 'jul'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' JULIO' 
        semanas_real.append(semana)
    if 'ago' in semana or 'ago'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' AGOSTO' 
        semanas_real.append(semana)
    if 'sep' in semana or 'sep'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' SEPTIEMBRE' 
        semanas_real.append(semana)
    if 'oct' in semana or 'oct'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' OCTUBRE' 
        semanas_real.append(semana)
    if 'nov' in semana or 'nov'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' NOVIEMBRE' 
        semanas_real.append(semana)
    if 'dic' in semana or 'dic'.upper() in semana:
        first_digit = semana[re.search("\d", semana).start():re.search("\d", semana).start() + 2]
        if is_int(first_digit[1]):
            first_digit = 1 + int(first_digit)
        else:
            first_digit = 1 + int(first_digit[0])
        semana = str(first_digit / 7 + 1) + ' DICIEMBRE' 
        semanas_real.append(semana)
    if semana_copy == semana:
        error_indices.append(error_index)
        
for error_index in error_indices:
    del semanas[error_index]

        
for i in range(len(semanas)):
    productos = productos.replace(semanas[i], semanas_real[i])
        
semanas = []
for semana in productos['SEMANA']:
    if not semana in semanas:
        semanas.append(semana)
semanas
# Out:
# ['4 AGOSTO',
#  '2 JULIO',
#  '3 JULIO',
#  '4 JULIO',
#  u'SEMANA DEL 21 AL 27 2012',
#  '5 JULIO',
#  '1 AGOSTO',
#  u'SEMANA DEL 4 A L 10 AGOSTO 2012',
#  '6 AGOSTO',
#  '2 AGOSTO',
#  '3 AGOSTO',
#  '1 SEPTIEMBRE',
#  u'SEMANA DEL 1 AL 7 DE SEPTIEMBRE 2012',
#  u'SEMANA  DEL 1 AL 7 DE SEPTIEMBRE 2012',
#  '2 SEPTIEMBRE',
#  '3 SEPTIEMBRE',
#  '4 SEPTIEMBRE',
#  '5 SEPTIEMBRE',
#  '5 OCTUBRE',
#  '2 OCTUBRE',
#  '3 OCTUBRE',
#  '4 OCTUBRE',
#  '1 OCTUBRE',
#  '1 NOVIEMBRE',
#  u'SEMANA DEL 3  AL 9  DE NOVIEMBRE  2012',
#  '2 NOVIEMBRE',
#  '4 NOVIEMBRE',
#  '3 NOVIEMBRE',
#  u'SEMANA DEL 10     DE16      DE NOVIEMBRE   2012',
#  u'SEMANA DE17       AL 23       DE NOVIEMBRE 2012',
#  u'SEMANA DEL 24      AL 30       DE  NOVIEMBRE  2012',
#  '1 DICIEMBRE',
#  '2 DICIEMBRE',
#  '3 DICIEMBRE',
#  '4 DICIEMBRE',
#  '5 ENERO',
#  '1 ENERO',
#  u'SEMANA DEL    5     AL 11       DE  ENERO  2013',
#  u'SEMANA D5          AL    11      DE  ENERO 2013  ',
#  '2 ENERO',
#  '3 ENERO',
#  '4 ENERO',
#  '1 FEBRERO',
#  '2 FEBRERO',
#  '3 FEBRERO',
#  u'SEMANA DEL  16    al   22       febrero   2013 ',
#  '4 FEBRERO',
#  u'SEMANA DEL  23   AL   1      febrero   2013 ',
#  '1 MARZO',
#  '2 MARZO',
#  u'SEMANA Del  2  al   8  marzo    2013 ',
#  '3 MARZO',
#  '4 MARZO',
#  u'SEMANA  DE 23  AL  29  DE MARZO    2013',
#  '5 MARZO',
#  '5 ABRIL',
#  '2 ABRIL',
#  '3 ABRIL',
#  '4 ABRIL',
#  '5 MAYO',
#  '1 MAYO',
#  '2 MAYO',
#  u'SEMANA DEL 11 AL  17 DE MAYO         2013  ',
#  '3 MAYO',
#  '4 MAYO',
#  '1 JUNIO',
#  '2 JUNIO',
#  '3 JUNIO',
#  '4 JUNIO',
#  '5 JUNIO',
#  '5 AGOSTO',
#  u'SEMANA DEL  7  AL 13 DE SEPTIEMBRE  DEL 2013 ',
#  '5 NOVIEMBRE',
#  '1 ABRIL',
#  '1 JULIO']

# %%
# Para el toque final, quitamos todas las excepciones
productos = productos.loc[productos['SEMANA'].str.contains('1 ENERO')|
							productos['SEMANA'].str.contains('2 ENERO')|
							productos['SEMANA'].str.contains('3 ENERO')|
							productos['SEMANA'].str.contains('4 ENERO')|
							productos['SEMANA'].str.contains('1 FEBRERO')|
							productos['SEMANA'].str.contains('2 FEBRERO')|
							productos['SEMANA'].str.contains('3 FEBRERO')|
							productos['SEMANA'].str.contains('4 FEBRERO')|
							productos['SEMANA'].str.contains('1 MARZO')|
							productos['SEMANA'].str.contains('2 MARZO')|
							productos['SEMANA'].str.contains('3 MARZO')|
							productos['SEMANA'].str.contains('4 MARZO')|
							productos['SEMANA'].str.contains('1 ABRIL')|
							productos['SEMANA'].str.contains('2 ABRIL')|
							productos['SEMANA'].str.contains('3 ABRIL')|
							productos['SEMANA'].str.contains('4 ABRIL')|
							productos['SEMANA'].str.contains('1 MAYO')|
							productos['SEMANA'].str.contains('2 MAYO')|
							productos['SEMANA'].str.contains('3 MAYO')|
							productos['SEMANA'].str.contains('4 MAYO')|
							productos['SEMANA'].str.contains('1 JUNIO')|
							productos['SEMANA'].str.contains('2 JUNIO')|
							productos['SEMANA'].str.contains('3 JUNIO')|
							productos['SEMANA'].str.contains('4 JUNIO')|
							productos['SEMANA'].str.contains('1 JULIO')|
							productos['SEMANA'].str.contains('2 JULIO')|
							productos['SEMANA'].str.contains('3 JULIO')|
							productos['SEMANA'].str.contains('4 JULIO')|
							productos['SEMANA'].str.contains('1 AGOSTO')|
							productos['SEMANA'].str.contains('2 AGOSTO')|
							productos['SEMANA'].str.contains('3 AGOSTO')|
							productos['SEMANA'].str.contains('4 AGOSTO')|
							productos['SEMANA'].str.contains('1 SEPTIEMBRE')|
							productos['SEMANA'].str.contains('2 SEPTIEMBRE')|
							productos['SEMANA'].str.contains('3 SEPTIEMBRE')|
							productos['SEMANA'].str.contains('4 SEPTIEMBRE')|
							productos['SEMANA'].str.contains('1 OCTUBRE')|
							productos['SEMANA'].str.contains('2 OCTUBRE')|
							productos['SEMANA'].str.contains('3 OCTUBRE')|
							productos['SEMANA'].str.contains('4 OCTUBRE')|
							productos['SEMANA'].str.contains('1 NOVIEMBRE')|
							productos['SEMANA'].str.contains('2 NOVIEMBRE')|
							productos['SEMANA'].str.contains('3 NOVIEMBRE')|
							productos['SEMANA'].str.contains('4 NOVIEMBRE')|
							productos['SEMANA'].str.contains('1 DICIEMBRE')|
							productos['SEMANA'].str.contains('2 DICIEMBRE')|
							productos['SEMANA'].str.contains('3 DICIEMBRE')|
							productos['SEMANA'].str.contains('4 DICIEMBRE')]

semanas = []
for semana in productos['SEMANA']:
    if not semana in semanas:
        semanas.append(semana)
semanas
# Out:
# ['4 AGOSTO',
#  '2 JULIO',
#  '3 JULIO',
#  '4 JULIO',
#  '1 AGOSTO',
#  '2 AGOSTO',
#  '3 AGOSTO',
#  '1 SEPTIEMBRE',
#  '2 SEPTIEMBRE',
#  '3 SEPTIEMBRE',
#  '4 SEPTIEMBRE',
#  '2 OCTUBRE',
#  '3 OCTUBRE',
#  '4 OCTUBRE',
#  '1 OCTUBRE',
#  '1 NOVIEMBRE',
#  '2 NOVIEMBRE',
#  '4 NOVIEMBRE',
#  '3 NOVIEMBRE',
#  '1 DICIEMBRE',
#  '2 DICIEMBRE',
#  '3 DICIEMBRE',
#  '4 DICIEMBRE',
#  '1 ENERO',
#  '2 ENERO',
#  '3 ENERO',
#  '4 ENERO',
#  '1 FEBRERO',
#  '2 FEBRERO',
#  '3 FEBRERO',
#  '4 FEBRERO',
#  '1 MARZO',
#  '2 MARZO',
#  '3 MARZO',
#  '4 MARZO',
#  '2 ABRIL',
#  '3 ABRIL',
#  '4 ABRIL',
#  '1 MAYO',
#  '2 MAYO',
#  '3 MAYO',
#  '4 MAYO',
#  '1 JUNIO',
#  '2 JUNIO',
#  '3 JUNIO',
#  '4 JUNIO',
#  '1 ABRIL',
#  '1 JULIO']

# %%
# La base de productos limpia!
productos
# Out:
#            PRODUCTO  CARGA EXISTENCIA DEVOLUCION  VENTA TOTAL PRECIO * PRODUC  \
# 60       PRODUCTO10    NaN        NaN          0          0.0             7.5
# 61      Queso Hebra    NaN        NaN          0          0.0              60
# 62     Queso fresco    NaN          0          0          0.0              12
# 63      Queso añejo    NaN          0          0          0.0              55
# 64     Queso panela    NaN          0          0          0.0              50
# 65        PRODUCTO4    NaN          0          0          0.0               6
# 67        PRODUCTO5    NaN          0          0          0.0              14
# 68        PRODUCTO1    NaN          0          0          0.0               9
# 69        PRODUCTO7    NaN          0          0          0.0               5
# 70        PRODUCTO3    NaN          0          0          0.0             7.5
# 71        PRODUCTO8    NaN          0          0          0.0               5
# 108      PRODUCTO10    NaN        NaN          0          0.0             7.5
# 109     Queso Hebra    NaN          0          0          0.0              60
# 110    Queso fresco    NaN          0          0          0.0              12
# 111     Queso añejo    NaN          0          0          0.0              55
# 112    Queso panela    NaN          0          0          0.0              50
# 113       PRODUCTO4    NaN          0          0          0.0               6
# 115       PRODUCTO5    NaN          0          0          0.0              14
# 116       PRODUCTO1    NaN          0          0          0.0               9
# 117       PRODUCTO7    NaN          0          0          0.0               5
# 118       PRODUCTO3    NaN          0          0          0.0             7.5
# 119       PRODUCTO8    NaN          0          0          0.0               5
# 216      PRODUCTO10  300.0        NaN        NaN        300.0            7.75
# 217     Queso Hebra    NaN        NaN        NaN          0.0              60
# 218    Queso fresco    NaN        NaN        NaN          0.0              12
# 219     Queso añejo    NaN        NaN        NaN          0.0              55
# 220    Queso panela    NaN        NaN        NaN          0.0              50
# 221       PRODUCTO4    NaN        NaN        NaN          0.0               6
# 223       PRODUCTO5    NaN        NaN        NaN          0.0              14
# 224       PRODUCTO1    NaN        NaN        NaN          0.0               7
# ...             ...    ...        ...        ...          ...             ...
# 90802   Queso añejo    NaN          0          0          0.0              55
# 90803  Queso panela    NaN          0          0          0.0              50
# 90804     PRODUCTO4    NaN          0          0          0.0               6
# 90806     PRODUCTO5    NaN          0          0          0.0              14
# 90807     PRODUCTO1    NaN          0          0          0.0               9
# 90808     PRODUCTO7    NaN          0          0          0.0               5
# 90809     PRODUCTO3    NaN          0          0          0.0             7.5
# 90810     PRODUCTO8    NaN          0          0          0.0               5
# 90835    PRODUCTO10    NaN        NaN          0          0.0             7.5
# 90836   Queso Hebra    NaN          0          0          0.0              60
# 90837  Queso fresco    NaN          0          0          0.0              12
# 90838   Queso añejo    NaN          0          0          0.0              55
# 90839  Queso panela    NaN          0          0          0.0              50
# 90840     PRODUCTO4    NaN          0          0          0.0               6
# 90842     PRODUCTO5    NaN          0          0          0.0              14
# 90843     PRODUCTO1    NaN          0          0          0.0               9
# 90844     PRODUCTO7    NaN          0          0          0.0               5
# 90845     PRODUCTO3    NaN          0          0          0.0             7.5
# 90846     PRODUCTO8    NaN          0          0          0.0               5
# 90907    PRODUCTO10  288.0        NaN        NaN        288.0             7.5
# 90908   Queso Hebra    NaN        NaN        NaN          0.0              60
# 90909  Queso fresco    NaN        NaN        NaN          0.0              12
# 90910   Queso añejo    NaN        NaN        NaN          0.0              55
# 90911  Queso panela    NaN        NaN        NaN          0.0              50
# 90912     PRODUCTO4    NaN        NaN        NaN          0.0               6
# 90914     PRODUCTO5    NaN        NaN        NaN          0.0              14
# 90915     PRODUCTO1    NaN        NaN        NaN          0.0               7
# 90916     PRODUCTO7    NaN        NaN        NaN          0.0               5
# 90917     PRODUCTO3    NaN        NaN        NaN          0.0             7.5
# 90918     PRODUCTO8    NaN        NaN        NaN          0.0               5
#
#             $  VENTA EN LT              RUTA      DIA    SEMANA  ANIO
# 60        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 61        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 62        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 63        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 64        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 65        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 67        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 68        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 69        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 70        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 71        0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2017
# 108       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 109       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 110       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 111       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 112       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 113       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 115       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 116       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 117       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 118       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 119       0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2017
# 216    2325.0        300.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 217       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 218       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 219       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 220       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 221       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 223       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# 224       0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2017
# ...       ...          ...               ...      ...       ...   ...
# 90802     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90803     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90804     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90806     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90807     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90808     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90809     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90810     0.0          0.0  RUTA: SAN MARCOS    LUNES  4 AGOSTO  2016
# 90835     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90836     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90837     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90838     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90839     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90840     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90842     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90843     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90844     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90845     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90846     0.0          0.0  RUTA: SAN MARCOS   MARTES  4 AGOSTO  2016
# 90907  2160.0        288.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90908     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90909     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90910     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90911     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90912     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90914     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90915     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90916     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90917     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
# 90918     0.0          0.0  RUTA: SAN MARCOS  VIERNES  4 AGOSTO  2016
#
# [16470 rows x 12 columns]

# %%
productos.to_pickle('productos_limpia')
